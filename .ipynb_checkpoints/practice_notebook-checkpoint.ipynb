# %%
import numpy as np
from PIL import Image
from astropy.io import fits

# %%
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)

# %%
image1 = Image.open('ngc602_ChandraHubbleSpitzer_960.jpg')
image2 = Image.open('solarorbiter.png')

# %%
xsize1, ysize1 = image1.size
print("Image size: {} x {}".format(xsize1, ysize1))
plt.imshow(image1)
# Out:
# Image size: 960 x 960

# %%
xsize2, ysize2 = image2.size
print("Image size: {} x {}".format(xsize2, ysize2))
plt.imshow(image2)
# Out:
# Image size: 1195 x 793

# %%
r, g, b = image1.split()

# %%
image1.split?
